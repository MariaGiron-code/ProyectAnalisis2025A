# %%
#pip install pymongo

# %%
#Eduardo Ganchala
from pymongo import MongoClient
import json
# Conexion con mongo db atlas
client=MongoClient("mongodb+srv://eduardoganchala29:jyxu5JIMqQk9JLtS@adcluster.hz5cw.mongodb.net/?retryWrites=true&w=majority&appName=ADCluster")

#Seleccionar base de datos
db= client["Datas"]
coleccion=db["Actividades_Hobbies"]


# Leer archivo JSON
with open("C:/ProyectAnalisis2025A/extract/Actividades.json", "r", encoding="utf-8") as f:
    data = json.load(f)
# Insertar datos
if isinstance(data, list):
    coleccion.insert_many(data)
else:
    coleccion.insert_one(data)

print("Datos subidos exitosamente a MongoDB Atlas")
# Out:
# Datos subidos exitosamente a MongoDB Atlas

# %%
from pymongo import MongoClient
import json
# Conexion con mongo db atlas
client=MongoClient("mongodb+srv://eduardoganchala29:jyxu5JIMqQk9JLtS@adcluster.hz5cw.mongodb.net/?retryWrites=true&w=majority&appName=ADCluster")

#Seleccionar base de datos
db= client["Datas"]
coleccion = db["Restaurantes"]  


# Leer archivo JSON
with open(r'C:/ProyectAnalisis2025A/extract/Reviews1.json', "r", encoding="utf-8") as f:
    data = json.load(f)
# Insertar datos
if isinstance(data, list):
    coleccion.insert_many(data)
else:
    coleccion.insert_one(data)

print("Datos subidos exitosamente a MongoDBAtlas")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Insertar datos
#      15 if isinstance(data, list):
# ---> 16     coleccion.insert_many(data)
#      17 else:
#      18     coleccion.insert_one(data)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2061, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2047 """Execute an operation with consecutive retries if possible
#    2048
#    2049 Returns func()'s return value on success. On error retries the same
#    (...)   2058 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2059 """
#    2060 with self._tmp_session(session) as s:
# -> 2061     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1942 # Ensure that the options supports retry_writes and there is a valid session not in
#    1943 # transaction, otherwise, we will not support retry behavior for this txn.
#    1944 retryable = bool(
#    1945     retryable and self.options.retry_writes and session and not session.in_transaction
#    1946 )
# -> 1947 return self._retry_internal(
#    1948     func=func,
#    1949     session=session,
#    1950     bulk=bulk,
#    1951     operation=operation,
#    1952     retryable=retryable,
#    1953     operation_id=operation_id,
#    1954 )
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1993, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1956 @_csot.apply
#    1957 def _retry_internal(
#    1958     self,
#    (...)   1967     operation_id: Optional[int] = None,
#    1968 ) -> T:
#    1969     """Internal retryable helper for all client transactions.
#    1970
#    1971     :param func: Callback function we want to retry
#    (...)   1980     :return: Output of the calling func()
#    1981     """
#    1982     return _ClientConnectionRetryable(
#    1983         mongo_client=self,
#    1984         func=func,
#    1985         bulk=bulk,
#    1986         operation=operation,
#    1987         is_read=is_read,
#    1988         session=session,
#    1989         read_pref=read_pref,
#    1990         address=address,
#    1991         retryable=retryable,
#    1992         operation_id=operation_id,
# -> 1993     ).run()
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2728 self._check_last_error(check_csot=True)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#    2735     self._check_last_error()
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2841, in _ClientConnectionRetryable._write(self)
#    2839 is_mongos = False
#    2840 self._server = self._get_server()
# -> 2841 with self._client._checkout(self._server, self._session) as conn:
#    2842     max_wire_version = conn.max_wire_version
#    2843     sessions_supported = (
#    2844         self._session
#    2845         and self._server.description.retryable_writes_supported
#    2846         and conn.supports_sessions
#    2847     )
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1756, in MongoClient._checkout(self, server, session)
#    1754     yield session._pinned_connection
#    1755     return
# -> 1756 with server.checkout(handler=err_handler) as conn:
#    1757     # Pin this session to the selected server or connection.
#    1758     if (
#    1759         in_txn
#    1760         and session
#    (...)   1765         )
#    1766     ):
#    1767         session._pin(server, conn)
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\pool.py:1119, in Pool.checkout(self, handler)
#    1110 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1111     _debug_log(
#    1112         _CONNECTION_LOGGER,
#    1113         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1116         serverPort=self.address[1],
#    1117     )
# -> 1119 conn = self._get_conn(checkout_started_time, handler=handler)
#    1121 duration = time.monotonic() - checkout_started_time
#    1122 if self.enabled_for_cmap:
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\pool.py:1281, in Pool._get_conn(self, checkout_started_time, handler)
#    1279 else:  # We need to create a new connection
#    1280     try:
# -> 1281         conn = self.connect(handler=handler)
#    1282     finally:
#    1283         with self._max_connecting_cond:
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\pool.py:1033, in Pool.connect(self, handler)
#    1023     _debug_log(
#    1024         _CONNECTION_LOGGER,
#    1025         message=_ConnectionStatusMessage.CONN_CREATED,
#    (...)   1029         driverConnectionId=conn_id,
#    1030     )
#    1032 try:
# -> 1033     networking_interface = _configured_socket_interface(self.address, self.opts)
#    1034 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1035 except BaseException as error:
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\pool_shared.py:500, in _configured_socket_interface(address, options)
#     493 def _configured_socket_interface(address: _Address, options: PoolOptions) -> NetworkingInterface:
#     494     """Given (host, port) and PoolOptions, return a NetworkingInterface wrapping a configured socket.
#     495
#     496     Can raise socket.error, ConnectionFailure, or _CertificateError.
#     497
#     498     Sets socket's SSL and timeout options.
#     499     """
# --> 500     sock = _create_connection(address, options)
#     501     ssl_context = options._ssl_context
#     503     if ssl_context is None:
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\pool_shared.py:404, in _create_connection(address, options)
#     401     family = socket.AF_UNSPEC
#     403 err = None
# --> 404 for res in socket.getaddrinfo(host, port, family=family, type=socket.SOCK_STREAM):  # type: ignore[attr-defined, unused-ignore]
#     405     af, socktype, proto, dummy, sa = res
#     406     # SOCK_CLOEXEC was new in CPython 3.2, and only available on a limited
#     407     # number of platforms (newer Linux and *BSD). Starting with CPython 3.4
#     408     # all file descriptors are created non-inheritable. See PEP 446.
#
# File c:\Users\DELL LATITUDE\AppData\Local\Programs\Python\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     974 # We override this function since we want to translate the numeric family
#     975 # and socket type values to enum constants.
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#     979     addrlist.append((_intenum_converter(af, AddressFamily),
#     980                      _intenum_converter(socktype, SocketKind),
#     981                      proto, canonname, sa))
#
# KeyboardInterrupt:

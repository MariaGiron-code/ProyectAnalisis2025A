# %%
# Instalaciones Necesarias
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 16.7 MB/s eta 0:00:01
# ...

# %%
#Importamso librerias Necesarias
import pandas as pd
from sqlalchemy import create_engine
from pymongo import MongoClient

# %%
# Crear cadena de conexión con sqlalchemy

# Cargar CSV
df = pd.read_csv("eventos_final.csv")

# Crear conexión
engine = create_engine('postgresql+psycopg2://postgres:12345@localhost:5432/Eventos_Futbol')

# Subir DataFrame como nueva tabla (se crea automáticamente)
df.to_sql('Events', con=engine, if_exists='replace', index=False)

#Leer la tabla para verificar que se creó correctamente (opcional)
df_pg = pd.read_sql('SELECT * FROM "Events"', engine)
print(df_pg.head())
# Out:
#   subEventName  playerId  matchId eventName  teamId matchPeriod   eventSec  \
# 0  Simple pass     25413  2499719      Pass    1609          1H   2.758649
# 1    High pass    370224  2499719      Pass    1609          1H   4.946850
# 2    Head pass      3319  2499719      Pass    1609          1H   6.542188
# 3    Head pass    120339  2499719      Pass    1609          1H   8.143395
# 4  Simple pass    167145  2499719      Pass    1609          1H  10.302366
#
#           id tagsList  pos_orig_y  pos_orig_x  pos_dest_y  pos_dest_x
# 0  177959171   [1801]          49          49          78          31
# 1  177959172   [1801]          78          31          75          51
# 2  177959173   [1801]          75          51          71          35
# 3  177959174   [1801]          71          35          95          41
# 4  177959175   [1801]          95          41          88          72

# %%
# Conexión a MongoDB Atlas
client = MongoClient("mongodb+srv://simbanaalexis2004:BwrZiZYZmz8QNLVs@adcluster.hz5cw.mongodb.net/?retryWrites=true&w=majority&appName=ADCluster")
db = client['Datas']
coleccion = db['Eventos_Futbol']

# %%
# Convertir DataFrame a diccionario de documentos
data = df.to_dict(orient='records')

# Insertar en la colección de MongoDB
coleccion.insert_many(data)
# Out:
# InsertManyResult([ObjectId('688e9e74d18702e06f2b4ad1'), ObjectId('688e9e74d18702e06f2b4ad2'), ObjectId('688e9e74d18702e06f2b4ad3'), ObjectId('688e9e74d18702e06f2b4ad4'), ObjectId('688e9e74d18702e06f2b4ad5'), ObjectId('688e9e74d18702e06f2b4ad6'), ObjectId('688e9e74d18702e06f2b4ad7'), ObjectId('688e9e74d18702e06f2b4ad8'), ObjectId('688e9e74d18702e06f2b4ad9'), ObjectId('688e9e74d18702e06f2b4ada'), ObjectId('688e9e74d18702e06f2b4adb'), ObjectId('688e9e74d18702e06f2b4adc'), ObjectId('688e9e74d18702e06f2b4add'), ObjectId('688e9e74d18702e06f2b4ade'), ObjectId('688e9e74d18702e06f2b4adf'), ObjectId('688e9e74d18702e06f2b4ae0'), ObjectId('688e9e74d18702e06f2b4ae1'), ObjectId('688e9e74d18702e06f2b4ae2'), ObjectId('688e9e74d18702e06f2b4ae3'), ObjectId('688e9e74d18702e06f2b4ae4'), ObjectId('688e9e74d18702e06f2b4ae5'), ObjectId('688e9e74d18702e06f2b4ae6'), ObjectId('688e9e74d18702e06f2b4ae7'), ObjectId('688e9e74d18702e06f2b4ae8'), ObjectId('688e9e74d18702e06f2b4ae9'), ObjectId('688e9e74d18702e06f2b
# ...

# %%
# Convertir a JSON
json_data = df.to_json(orient='records', indent=2)

# Guardar en un archivo
with open('Events_Soccer.json', 'w', encoding='utf-8') as f:
    f.write(json_data)

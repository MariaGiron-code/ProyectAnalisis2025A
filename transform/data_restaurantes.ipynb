# %%
import pandas as pd

# %%
# DEFINICION DE LA RUTA DEL ARCHIVO
ruta_origen = 'C:/ProyectAnalisis2025A/extract/Reviews.csv'
df = pd.read_csv(ruta_origen)
# VISUALIZACION DE LOS DATOS
print("Filas originales: ",len(df))
df.head()
# Out:
# Filas originales:  568454
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# ELIMINACION DE COLUMNAS INNECESARIAS
df1 = df[['Id', 'ProductId', 'UserId', 'Score', 'Time', 'Summary', 'Text']]
# ELIMINACION DE DUPLICADOS Y NULOS 
df1 = df.drop_duplicates()
df1 = df.dropna(subset=['Summary', 'Text'])
# CONVERTIR LA FECHA EN TIPO LEGIBLE 
df1['Time'] = pd.to_datetime(df1['Time'], unit='s')
# Out:
# C:\Users\DELL LATITUDE\AppData\Local\Temp\ipykernel_18084\517165129.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Time'] = pd.to_datetime(df1['Time'], unit='s')

# %%
# LIMPIEZA DE TEXTO 
import re
def limpiar_texto(texto):
    texto = texto.lower()  # Convertir a minúsculas
    texto = re.sub(r'[^a-zA-Z0-9\s]', '', texto)
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto
df1['Summary'] = df1['Summary'].apply(limpiar_texto)
df1['Text'] = df1['Text'].apply(limpiar_texto)
# Out:
# C:\Users\DELL LATITUDE\AppData\Local\Temp\ipykernel_18084\3088436093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Summary'] = df1['Summary'].apply(limpiar_texto)
# C:\Users\DELL LATITUDE\AppData\Local\Temp\ipykernel_18084\3088436093.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Text'] = df1['Text'].apply(limpiar_texto)

# %%
ruta_destino = 'C:/ProyectAnalisis2025A/extract/Reviews_clean.csv'
df1.to_csv(ruta_destino, index=False,encoding='utf-8-sig')
print("Datos transformados y guardados en:", ruta_destino)
# VERIFICACION DEL DOCUMENTO CORRECTO 
df_verificacion = pd.read_csv(ruta_destino)
print("Filas en el archivo guardado:", len(df_verificacion))
df_verificacion.head()
# Out:
# Datos transformados y guardados en: C:/ProyectAnalisis2025A/extract/Reviews_clean.csv
# Filas en el archivo guardado: 568427
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  2011-04-27
# 1                     0                       0      1  2012-09-07
# 2                     1                       1      4  2008-08-18
# 3                     3                       3      2  2011-06-13
# 4                     0                       0      5  2012-10-21
#
#                  Summary                                               Text
# 0  good quality dog food  i have bought several of the vitality canned d...
# 1      not as advertised  product arrived labeled as jumbo salted peanut...
# 2    delight says it all  this is a confection that has been around a fe...
# 3         cough medicine  if you are looking for the secret ingredient i...
# 4            great taffy  great taffy at a great price there was a wide ...
